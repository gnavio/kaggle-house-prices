# %%
import pandas as pd
import numpy as np
from sklearn.metrics import auc, accuracy_score, confusion_matrix, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold, RandomizedSearchCV, train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb

# %%
train = pd.read_csv('../input/house-prices-advanced-regression-techniques/train.csv')
test = pd.read_csv('../input/house-prices-advanced-regression-techniques/test.csv')
train

# %%
train_new = pd.get_dummies(train, columns = ['MSSubClass','MSZoning','Street','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood','Condition1','Condition2','BldgType','HouseStyle','YearBuilt','YearRemodAdd','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','ExterQual','ExterCond','Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','Heating','HeatingQC','CentralAir','Electrical','KitchenQual','Functional','FireplaceQu','GarageType','GarageYrBlt','GarageFinish','GarageQual','GarageCond','PavedDrive','PoolQC','Fence','MiscFeature','MoSold','YrSold','SaleType','SaleCondition'])

# %%
train_new.dropna(axis = 1, inplace = True)
for i in train_new.columns:
    print(i)

# %%
X = np.array(train_new.drop(['BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath',
       'BsmtHalfBath', 'GarageCars', 'SalePrice',
       'Utilities_NoSeWa', 'Condition2_RRAe', 'Condition2_RRAn',
       'Condition2_RRNn', 'HouseStyle_2.5Fin', 'YearBuilt_1872',
       'YearBuilt_1875', 'YearBuilt_1882', 'YearBuilt_1885', 'YearBuilt_1892',
       'YearBuilt_1893', 'YearBuilt_1898', 'YearBuilt_1904', 'YearBuilt_1906',
       'YearBuilt_1908', 'YearBuilt_1911', 'YearBuilt_1913',
       'RoofMatl_ClyTile', 'RoofMatl_Membran', 'RoofMatl_Metal',
       'RoofMatl_Roll', 'Exterior1st_ImStucc', 'Exterior1st_Stone',
       'Exterior2nd_Other', 'Heating_Floor', 'Heating_OthW', 'Electrical_Mix',
       'GarageYrBlt_1906.0', 'GarageYrBlt_1908.0', 'GarageYrBlt_1914.0',
       'GarageYrBlt_1929.0', 'GarageYrBlt_1931.0', 'GarageYrBlt_1933.0',
       'GarageQual_Ex', 'PoolQC_Fa', 'MiscFeature_TenC','GarageArea'],axis = 1))
Y = np.array(train_new['SalePrice'])

# %%
X = np.array(train_new[['LotArea','MSZoning_C (all)','MSZoning_FV','MSZoning_RH','MSZoning_RL','MSZoning_RM',
                        'Utilities_AllPub','BldgType_1Fam','BldgType_2fmCon','BldgType_Duplex','BldgType_Twnhs'
                        ,'BldgType_TwnhsE','OverallQual','PoolArea','MiscVal']])

# %%
one_array = []
two_array = []
three_array = []
four_array = []
five_array = []
six_array = []
seven_array = []
eight_array = []
nine_array = []
ten_array = []
pos = 0
for i in train_new['OverallQual']:
    if i == 1:
        one_array.append(train_new['SalePrice'].values[pos])
    if i == 2:
        two_array.append(train_new['SalePrice'].values[pos])
    if i == 3:
        three_array.append(train_new['SalePrice'].values[pos])
    if i == 4:
        four_array.append(train_new['SalePrice'].values[pos])
    if i == 5:
        five_array.append(train_new['SalePrice'].values[pos])
    if i == 6:
        six_array.append(train_new['SalePrice'].values[pos])
    if i == 7:
        seven_array.append(train_new['SalePrice'].values[pos])
    if i == 8:
        eight_array.append(train_new['SalePrice'].values[pos])
    if i == 9:
        nine_array.append(train_new['SalePrice'].values[pos])
    if i == 10:
        ten_array.append(train_new['SalePrice'].values[pos])
    pos = pos + 1
mean = [np.mean(one_array),np.mean(two_array),np.mean(three_array),np.mean(four_array),np.mean(five_array)
                 ,np.mean(six_array),np.mean(seven_array),np.mean(eight_array),np.mean(nine_array),np.mean(ten_array)]
plt.plot(mean,'.')

# %%
one_array = []
two_array = []
three_array = []
four_array = []
five_array = []
six_array = []
seven_array = []
eight_array = []
nine_array = []
ten_array = []
pos = 0
for i in train_new['OverallCond']:
    if i == 1:
        one_array.append(train_new['SalePrice'].values[pos])
    if i == 2:
        two_array.append(train_new['SalePrice'].values[pos])
    if i == 3:
        three_array.append(train_new['SalePrice'].values[pos])
    if i == 4:
        four_array.append(train_new['SalePrice'].values[pos])
    if i == 5:
        five_array.append(train_new['SalePrice'].values[pos])
    if i == 6:
        six_array.append(train_new['SalePrice'].values[pos])
    if i == 7:
        seven_array.append(train_new['SalePrice'].values[pos])
    if i == 8:
        eight_array.append(train_new['SalePrice'].values[pos])
    if i == 9:
        nine_array.append(train_new['SalePrice'].values[pos])
    if i == 10:
        ten_array.append(train_new['SalePrice'].values[pos])
    pos = pos + 1
mean = [np.mean(one_array),np.mean(two_array),np.mean(three_array),np.mean(four_array),np.mean(five_array)
                 ,np.mean(six_array),np.mean(seven_array),np.mean(eight_array),np.mean(nine_array),np.mean(ten_array)]
plt.plot(mean,'.')

# %%
test_new = pd.get_dummies(test, columns = ['MSSubClass','MSZoning','Street','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood','Condition1','Condition2','BldgType','HouseStyle','YearBuilt','YearRemodAdd','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','ExterQual','ExterCond','Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','Heating','HeatingQC','CentralAir','Electrical','KitchenQual','Functional','FireplaceQu','GarageType','GarageYrBlt','GarageFinish','GarageQual','GarageCond','PavedDrive','PoolQC','Fence','MiscFeature','MoSold','YrSold','SaleType','SaleCondition'])

# %%
xgb_model = xgb.XGBRegressor(objective="reg:linear", random_state=42, n_estimators=1000, learning_rate=0.05)

xgb_model.fit(X, Y)

Y_pred = xgb_model.predict(X)

mse=mean_squared_error(Y, Y_pred)

print(np.sqrt(mse))

# %%
dif = train_new.columns.symmetric_difference(test_new.columns)

# %%
train_new.columns & dif

# %%
test_new.columns & dif

# %%
test_new.drop(['MSSubClass_150', 'YearBuilt_1879', 'YearBuilt_1895', 'YearBuilt_1896',
       'YearBuilt_1901', 'YearBuilt_1902', 'YearBuilt_1907',
       'GarageYrBlt_1895.0', 'GarageYrBlt_1896.0', 'GarageYrBlt_1917.0',
       'GarageYrBlt_1919.0', 'GarageYrBlt_1943.0', 'GarageYrBlt_2207.0'], axis = 1, inplace = True)

# %%
test_new

# %%
test_new.dropna(axis = 1, inplace = True)
X_test = np.array(test_new[['LotArea','MSZoning_C (all)','MSZoning_FV','MSZoning_RH','MSZoning_RL','MSZoning_RM',
                        'Utilities_AllPub','BldgType_1Fam','BldgType_2fmCon','BldgType_Duplex','BldgType_Twnhs'
                        ,'BldgType_TwnhsE','OverallQual','PoolArea','MiscVal']])

# %%
X.shape

# %%
X_test.shape

# %%
Y_pred_test = xgb_model.predict(X_test)

# %%
Y_pred_test

# %%
predict = Y_pred_test.tolist()
test_new['SalePrice'] = predict
final_predict = test_new[['Id','SalePrice']]
final_predict.to_csv(path_or_buf = r'./House_final_predict_XGB.csv', index = False)
